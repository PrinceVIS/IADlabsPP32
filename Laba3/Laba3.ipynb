# %%
import pandas as pnd
import numpy as nmp
import seaborn as sb
import matplotlib.pyplot as plot

data = pnd.read_csv('Life Expectancy Data.csv')

data
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
data.head(20)
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 0   Afghanistan  2015  Developing              65.0            263.0
# 1   Afghanistan  2014  Developing              59.9            271.0
# 2   Afghanistan  2013  Developing              59.9            268.0
# 3   Afghanistan  2012  Developing              59.5            272.0
# 4   Afghanistan  2011  Developing              59.2            275.0
# 5   Afghanistan  2010  Developing              58.8            279.0
# 6   Afghanistan  2009  Developing              58.6            281.0
# 7   Afghanistan  2008  Developing              58.1            287.0
# 8   Afghanistan  2007  Developing              57.5            295.0
# 9   Afghanistan  2006  Developing              57.3            295.0
# 10  Afghanistan  2005  Developing              57.3            291.0
# 11  Afghanistan  2004  Developing              57.0            293.0
# 12  Afghanistan  2003  Developing              56.7            295.0
# ...

# %%
data.nsmallest(20, ['infant deaths'])
# Out:
#                 Country  Year      Status  Life expectancy   Adult Mortality  \
# 16              Albania  2015  Developing              77.8             74.0
# 17              Albania  2014  Developing              77.5              8.0
# 18              Albania  2013  Developing              77.2             84.0
# 19              Albania  2012  Developing              76.9             86.0
# 20              Albania  2011  Developing              76.6             88.0
# 64  Antigua and Barbuda  2015  Developing              76.4             13.0
# 65  Antigua and Barbuda  2014  Developing              76.2            131.0
# 66  Antigua and Barbuda  2013  Developing              76.1            133.0
# 67  Antigua and Barbuda  2012  Developing              75.9            134.0
# 68  Antigua and Barbuda  2011  Developing              75.7            136.0
# 69  Antigua and Barbuda  2010  Developing              75.6            138.0
# ...

# %%
data.nlargest(10, ['Life expectancy '])
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 241       Belgium  2014   Developed              89.0             76.0
# 915       Finland  2014  Developing              89.0             78.0
# 937        France  2008  Developing              89.0             88.0
# 938        France  2007  Developing              89.0             89.0
# 995       Germany  2014   Developed              89.0             69.0
# 1293        Italy  2004   Developed              89.0             66.0
# 1850  New Zealand  2010   Developed              89.0             71.0
# 1916       Norway  2009   Developed              89.0             67.0
# 2056     Portugal  2014   Developed              89.0             78.0
# 2433        Spain  2007   Developed              89.0             72.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 241               0    12.60             7163.348923         98.0        70
# ...

# %%
print('Hispilot')
# Out:
# Hispilot

# %%
sb.histplot(data=data.dropna(subset=['Life expectancy ']), x="Life expectancy ", color="red")
sb.histplot(data=data.dropna(subset=['GDP']), x="Life expectancy ", color="skyblue")
# Out:
# <AxesSubplot: xlabel='Life expectancy ', ylabel='Count'>

# %%
print('rugplot')

# %%
dataDropna = data.dropna(subset=[' BMI '])
sb.histplot(data=dataDropna, x="infant deaths", color="skyblue")
sb.rugplot(data=dataDropna, x = 'infant deaths', y = 'GDP')
# Out:
# <AxesSubplot: xlabel='infant deaths', ylabel='Count'>

# %%
print('boxplot')
dataDropna = data.dropna(subset=['Schooling'])
sb.boxplot(x = dataDropna['Schooling'])
# Out:
# boxplot
# <AxesSubplot: xlabel='Schooling'>

# %%
print("Коваріація")

data.cov()
# Out:
# Коваріація
# C:\Users\romac\AppData\Local\Temp\ipykernel_15772\202327415.py:3: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.cov()
#                                          Year  Life expectancy   \
# Year                             2.119694e+01      7.402848e+00
# Life expectancy                  7.402848e+00      9.291774e+01
# Adult Mortality                 -4.239569e+01     -8.340523e+02
# infant deaths                   -2.187722e+01     -2.256784e+02
# Alcohol                         -8.493275e-01      1.504177e+01
# percentage expenditure           3.609059e+02      8.409123e+03
# Hepatitis B                      9.723530e+00      5.124743e+01
# Measles                         -4.793838e+03     -1.593289e+04
#  BMI                             8.979814e+00      1.110229e+02
# ...

# %%
print("Коваріація")

data.cov()
# Out:
# Коваріація
# C:\Users\romac\AppData\Local\Temp\ipykernel_15772\1367650487.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.166880        -0.073018
# Life expectancy                  0.166880          1.000000        -0.685798
# Adult Mortality                 -0.073018         -0.685798         1.000000
# infant deaths                   -0.037378         -0.183986         0.065921
# Alcohol                         -0.048682          0.384486        -0.175809
# percentage expenditure           0.036608          0.407029        -0.252149
# Hepatitis B                      0.088562          0.239024        -0.143081
# ...

# %%
print("Кореляція")

dataDropna = data.drop(columns=['Year', 'Life expectancy ', 'Adult Mortality', 'Alcohol', 'under-five deaths '])
corelated = dataDropna.corr()
plot.figure(figsize=(12,18))

map = sb.diverging_palette(450, 120, s=75, l=40, n=9, center="light", as_cmap=True)
_ = sb.heatmap(corelated, center=0, annot=True, fmt='.3f', square=True, cmap=map)
# Out:
# Кореляція
# C:\Users\romac\AppData\Local\Temp\ipykernel_15772\1952696320.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corelated = dataDropna.corr()

# %%
print('Дисперсія')
print('Life expectancy дисперсія: ', data["Life expectancy "].var())
print('Alcohol дисперсія: ', data["Alcohol"].var())
print('Hepatitis B дисперсія: ', data["Hepatitis B"].var())
print('Percentage expenditure дисперсія: ', data["percentage expenditure"].var())
# Out:
# Дисперсія
# Life expectancy дисперсія:  92.91774400980499
# Alcohol дисперсія:  16.23928831077349
# Hepatitis B дисперсія:  627.7609516919862
# Percentage expenditure дисперсія:  4585263.5719384

# %%
plot.figure(figsize=(4, 4))
plot.style.use('_mpl-gallery')
dataset3= data.dropna(subset=['Life expectancy ', 'Schooling'])
sb.scatterplot(data=dataset3, x="Life expectancy ", y="Schooling", hue="Status", style="Status")
# Out:
# <AxesSubplot: xlabel='Life expectancy ', ylabel='Schooling'>

# %%
f = ['Adult Mortality','infant deaths','Alcohol',' BMI ','under-five deaths ','Population']
print("Початкові дані")
for i in nmp.arange(0,6):
    result = data[f[i]].corr(data['Life expectancy '])
    if(-0.09<=result<=0 or 0<= result<=0.09): print(f[i], " Кореляції немає ", result)
    if(-0.3<result<=-0.1or 0.1<=result<0.3): print(f[i], " Низька кореляція", result)
    if(-0.5<result<=-0.3or 0.3<=result<0.5): print(f[i], " Середня кореляція", result)
    if(-1<=result<=-0.5 or 0.5<=result<=1): print(f[i], " Висока кореляція", result)
factors = [
 'Adult Mortality',
 'infant deaths',
 'Alcohol',
 'percentage expenditure',
 'Hepatitis B',
 'Measles ',
 ' BMI ',
 'under-five deaths ',
 'Polio',
 'Total expenditure',
 'Diphtheria ',
 ' HIV/AIDS',
 'GDP',
 'Population',
 ' thinness  1-19 years',
 ' thinness 5-9 years',
 'Income composition of resources',
 'Schooling']
print(" ")
print("Чинники, що впливають на середню тривалість життя")
for i in nmp.arange(0, 18):
    result = data[factors[i]].corr(data['Life expectancy '])
    if(-0.5<result<=-0.3or 0.3<=result<0.5): print(factors[i], " Середня ", result)
    if(-1<=result<=-0.5 or 0.5<=result<=1): print(factors[i], " Висока ", result)
# Out:
# Початкові дані
# Adult Mortality  Висока  -0.6857982992333999
# infant deaths  Низька  -0.18398571285088106
# Alcohol  Середня  0.3844860023541831
#  BMI   Висока  0.5785423005868717
# under-five deaths   Низька  -0.20936339248339436
# Population  Кореляція відсутня  -0.023097061621138216
#
# Чинники, що впливають на середню тривалість життя
# Adult Mortality  Висока  -0.6857982992333999
# Alcohol  Середня  0.3844860023541831
# percentage expenditure  Середня  0.407028619658389
#  BMI   Висока  0.5785423005868717
# Polio  Середня  0.45692927402823513
# Diphtheria   Середня  0.46881209462214785
#  HIV/AIDS  Висока  -0.5710411251403368
# GDP  Середня  0.46006811938985964
#  thinness  1-19 years  Середня  -0.480920833496379
#  thinness 5-9 years  Середня  -0.4767780255508318
# Income composition of resources  Висока  0.7327342712426748
# Schooling  Висока  0.7545033014091087

# %%
print('Чи повинна країна з нижчим значенням очікуваної тривалості життя (<65) збільшити витрати на охорону здоров’я, щоб покращити середню тривалість життя?')
lessThan65 = data[data['Life expectancy ']<65]
lessThan65_example = lessThan65.sample(n = 20)
fig, ax = plot.subplots()
plot.title("Life Expectancy")
ax.set_xticks(nmp.arange(20, 65))
ax = sb.scatterplot(lessThan65_example, x='Life expectancy ', y ='Total expenditure', hue = 'Country', )
sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plot.show()

lessThan65cor = lessThan65['Total expenditure'].corr(lessThan65['Life expectancy '])
print("Health care costs depend on the average life expectancy:")
if(-0.09<=lessThan65cor<=0 or 0<= lessThan65cor<=0.09): print(" Кореляція відсутня ", lessThan65cor)
if(-0.3<lessThan65cor<=-0.1or 0.1<=lessThan65cor<0.3): print(" Низьку ", lessThan65cor)
if(-0.5<lessThan65cor<=-0.3or 0.3<=lessThan65cor<0.5): print( " Середню ", lessThan65cor)
if(-1<=lessThan65cor<=-0.5 or 0.5<=lessThan65cor<=1): print( " Високу ", lessThan65cor)
# Out:
# Чи повинна країна з нижчим значенням очікуваної тривалості життя (<65) збільшити витрати на охорону здоров’я, щоб покращити середню тривалість життя?
# Health care costs depend on the average life expectancy:
#  Низьку  -0.17091530569230914

# %%
print('Як рівень дитячої та дорослої смертності впливає на тривалість життя?')
# Out:
# Як рівень дитячої та дорослої смертності впливає на тривалість життя?

# %%
fewCountries =data.sample(n = 10)
fig, x= plot.subplots()
x = sb.scatterplot(fewCountries, x='Life expectancy ', y ='infant deaths', hue = 'Country')
sb.move_legend(x, "upper left", bbox_to_anchor=(1, 1))
plot.show()

# %%
print('Чи має очікувана тривалість життя позитивну чи негативну кореляцію зі звичками в їжі, способом життя, фізичними вправами, курінням, вживанням алкоголю тощо.')

alcoholCorr = data['Life expectancy '].corr(data['Alcohol'])
bmiCorr = data['Life expectancy '].corr(data[' BMI '])

if alcoholCorr >= 0 : print('Alcohol affects positive')
else: print('Alcohol affects negative')

if bmiCorr >= 0 : print('BMI affects positive')
else: print('BMI affects negative')
# Out:
# Чи має очікувана тривалість життя позитивну чи негативну кореляцію зі звичками в їжі, способом життя, фізичними вправами, курінням, вживанням алкоголю тощо.
# Alcohol affects positive
# BMI affects positive

# %%
print('Який вплив навчання в школі на тривалість життя людини?')

schoolingCorr = data['Life expectancy '].corr(data['Schooling'])
print('Affection schooling on life expectancy: ')
if(-0.9<=schoolingCorr<=0 or 0<= schoolingCorr<=0.09): print(" not affect", schoolingCorr)

if(-0.3<schoolingCorr<=-0.1or 0.1<=schoolingCorr<0.3): print("low affect", schoolingCorr)

if(-0.5<schoolingCorr<=-0.3or 0.3<=schoolingCorr<0.5): print("average affect", schoolingCorr)

if(-1<=schoolingCorr<=-0.5 or 0.5<=schoolingCorr<=1): print("high affect", schoolingCorr)
# Out:
# Який вплив навчання в школі на тривалість життя людини?
# Affection schooling on life expectancy:
# high affect 0.7545033014091087

# %%
print('Позитивний чи негативний зв’язок очікуваної тривалості життя з вживанням алкоголю?')

alcoholCorr = data['Life expectancy '].corr(data['Alcohol'])

if alcoholCorr >= 0 : print('Alcohol affects positive')
else: print('Alcohol affects negative')
# Out:
# Позитивний чи негативний зв’язок очікуваної тривалості життя з вживанням алкоголю?
# Alcohol affects positive

# %%
print('Чи зазвичай у густонаселених країнах тривалість життя нижча?')
sortedCountries = data.sort_values(by ='Population' ,ascending = False).head(50)
fig, x= plot.subplots()
x = sb.scatterplot(sortedCountries, x='Life expectancy ', y ='Population', hue = 'Country')
sb.move_legend(x, "upper left", bbox_to_anchor=(1, 1))
plot.show()
# Out:
# Чи зазвичай у густонаселених країнах тривалість життя нижча?

# %%
print('Який вплив охоплення імунізацією на очікувану тривалість життя?')

schoolingCorr = data['Life expectancy '].corr(data['Schooling'])
print('Affection imunnization on life expectancy: ')
if(-0.9<=schoolingCorr<=0 or 0<= schoolingCorr<=0.09): print(" not affect", schoolingCorr)

if(-0.3<schoolingCorr<=-0.1or 0.1<=schoolingCorr<0.3): print("low affect", schoolingCorr)

if(-0.5<schoolingCorr<=-0.3or 0.3<=schoolingCorr<0.5): print("average affect", schoolingCorr)

if(-1<=schoolingCorr<=-0.5 or 0.5<=schoolingCorr<=1): print("high affect", schoolingCorr)
# Out:
# Який вплив охоплення імунізацією на очікувану тривалість життя?
# Affection imunnization on life expectancy:
# high affect 0.7545033014091087
