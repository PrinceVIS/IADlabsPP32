# %%
import numpy as np
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

# %%
LED = ['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality','infant deaths','Alcohol','percentage expenditure','Hepatitis B','Measles','BMI','under-five deaths','Polio','Total expenditure','Diphtheria','HIV/AIDS','GDP','Population','thinness  1-19 years','thinness 5-9 years','Income composition of resources','Schooling']

# %%
LifeExData = pd.read_table("Life_Expectancy_Data_Ext.csv", sep = ",", engine ='python', names = LED)

# %%
LifeExData
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
countryName = pd.unique(LifeExData['Country'])
sb.set(style="darkgrid")

for i in np.arange(5):
    fig, ax = plt.subplots()
    plt.title(countryName[i])
    ax.set_xticks(np.arange(2000, 2016))
    plt.xticks(rotation=45)
    sb.histplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='Adult Mortality', color = 'r', bins = 30)
    sb.rugplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='Adult Mortality', color = 'r')
    
    fig, p = plt.subplots()
    plt.xticks(rotation=45)
    p.set_xticks(np.arange(2000, 2016))
    sb.histplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='infant deaths', color = 'g', bins = 30)
    sb.rugplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='infant deaths', color = 'g')
    
    fig, p2 = plt.subplots()
    plt.xticks(rotation=45)
    p2.set_xticks(np.arange(2000, 2016))
    plt.xticks(rotation=45)
    sb.histplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='Hepatitis B', color = 'y',bins = 30)
    sb.rugplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='Hepatitis B', color = 'y')
    
    fig, p3 = plt.subplots()
    plt.xticks(rotation=45)
    p3.set_xticks(np.arange(2000, 2016))
    sb.histplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='Measles', color = 'black', bins = 30)
    sb.rugplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='Measles', color = 'black')
    
    fig, p4 = plt.subplots()
    plt.xticks(rotation=45)
    p4.set_xticks(np.arange(2000, 2016))
    plt.xticks(rotation=45)
    sb.histplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='under-five deaths', color = 'b', bins = 30)
    sb.rugplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='under-five deaths', color = 'b')
    
    fig, p5 = plt.subplots()
    plt.xticks(rotation=45)
    p5.set_xticks(np.arange(2000, 2016))
    plt.xticks(rotation=45)
    sb.histplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='Diphtheria', color = 'orange', bins = 30)
    sb.rugplot(LifeExData[LifeExData['Country']==countryName[i]], x='Year', y ='Diphtheria', color = 'orange')

    plt.show()

# %% [markdown]
# Обрахувати – дисперсію, коваріацію та кореляцію по факторах. Зробити порівняльний аналіз між факторами.

# %%
j=0
cov = np.zeros(18)
for i in np.arange(4, 22):
    factor = LED[i]
    cov[j] = LifeExData['Life expectancy'].cov(LifeExData[factor])
    print("Коваріація Life expectancy з ",LED[i],":",cov[j])
    j+=1
# Out:
# Коваріація Life expectancy з  Adult Mortality : -824.3092725351494
# Коваріація Life expectancy з  infant deaths : -221.10841937510384
# Коваріація Life expectancy з  Alcohol : 15.664345358268612
# Коваріація Life expectancy з  percentage expenditure : 7240.651074614019
# Коваріація Life expectancy з  Hepatitis B : 54.12235874606482
# Коваріація Life expectancy з  Measles : -17238.44741333281
# Коваріація Life expectancy з  BMI : 107.50743395213696
# Коваріація Life expectancy з  under-five deaths : -340.57874586243406
# Коваріація Life expectancy з  Polio : 103.50244803042116
# Коваріація Life expectancy з  Total expenditure : 5.161025136672523
# Коваріація Life expectancy з  Diphtheria : 107.92143576378959
# Коваріація Life expectancy з  HIV/AIDS : -26.9562633951658
# Коваріація Life expectancy з  GDP : 63572.57373527012
# Коваріація Life expectancy з  Population : -12920104.178093303
# Коваріація Life expectancy з  thinness  1-19 years : -20.01528536054733
# ...

# %%
j=0
corCoef = np.zeros(18)
for i in np.arange(4, 22):
    factor = LED[i]
    corCoef[j]= LifeExData['Life expectancy'].corr(LifeExData[factor])
    print("Кореляція",LED[i],corCoef[j])
    j+=1
# Out:
# Кореляція Adult Mortality -0.6963593137699758
# Кореляція infant deaths -0.19655717665526165
# Кореляція Alcohol 0.40487676112660204
# Кореляція percentage expenditure 0.3818635033900497
# Кореляція Hepatitis B 0.2567619476049244
# Кореляція Measles -0.15758580377505835
# Кореляція BMI 0.5676935475459864
# Кореляція under-five deaths -0.2225291159511754
# Кореляція Polio 0.4655558059771987
# Кореляція Total expenditure 0.2180863736916715
# Кореляція Diphtheria 0.47949486434158567
# Кореляція HIV/AIDS -0.5565562534006939
# Кореляція GDP 0.46145519262073825
# Кореляція Population -0.021538108386786478
# Кореляція thinness  1-19 years -0.4771831915723341
# Кореляція thinness 5-9 years -0.4715836048009973
# Кореляція Income composition of resources 0.7247759785960612
# Кореляція Schooling 0.7519754627366979

# %%
j=0
var = np.zeros(18)
for i in np.arange(4, 22):
    factor = LED[i]
    var[j] = LifeExData[factor].var()
    print("Дисперсія",LED[i],var[j])
    j+=1
# Out:
# Дисперсія Adult Mortality 15448.520902992863
# Дисперсія infant deaths 13906.659712019115
# Дисперсія Alcohol 16.422048356843128
# Дисперсія percentage expenditure 3951805.482721534
# Дисперсія Hepatitis B 628.5056818341706
# Дисперсія Measles 131498338.34235719
# Дисперсія BMI 401.76327905183103
# Дисперсія under-five deaths 25742.77400321663
# Дисперсія Polio 548.8733370104072
# Дисперсія Total expenditure 6.241601184279822
# Дисперсія Diphtheria 562.4919180684044
# Дисперсія HIV/AIDS 25.783895744141844
# Дисперсія GDP 203637733.03554255
# Дисперсія Population 3722475920353723.0
# Дисперсія thinness  1-19 years 19.538123370760182
# Дисперсія thinness 5-9 years 20.330017674316203
# Дисперсія Income composition of resources 0.04448030957558102
# Дисперсія Schooling 11.28234169281033

# %%
Fact = ['Adult Mortality','infant deaths','Alcohol','percentage expenditure','Hepatitis B','Measles','BMI','under-five deaths','Polio','Total expenditure','Diphtheria','HIV/AIDS','GDP','Population','thinness  1-19 years','thinness 5-9 years','Income composition of resources','Schooling']
allData = zip(Fact,cov,corCoef,var)
rezCol = ['Фактор','Коваріація','Кореляція','Дисперсія']
Rez = pd.DataFrame(data=allData, columns = rezCol)
Rez
# Out:
#                              Фактор    Коваріація  Кореляція     Дисперсія
# 0                   Adult Mortality -8.243093e+02  -0.696359  1.544852e+04
# 1                     infant deaths -2.211084e+02  -0.196557  1.390666e+04
# 2                           Alcohol  1.566435e+01   0.404877  1.642205e+01
# 3            percentage expenditure  7.240651e+03   0.381864  3.951805e+06
# 4                       Hepatitis B  5.412236e+01   0.256762  6.285057e+02
# 5                           Measles -1.723845e+04  -0.157586  1.314983e+08
# 6                               BMI  1.075074e+02   0.567694  4.017633e+02
# 7                 under-five deaths -3.405787e+02  -0.222529  2.574277e+04
# 8                             Polio  1.035024e+02   0.465556  5.488733e+02
# 9                 Total expenditure  5.161025e+00   0.218086  6.241601e+00
# 10                       Diphtheria  1.079214e+02   0.479495  5.624919e+02
# ...

# %%
sb.catplot(Rez, y='Кореляція', hue='Фактор')

# %%
sb.catplot(Rez, y='Коваріація', hue='Фактор')

# %%
sb.catplot(Rez, y='Дисперсія', hue='Фактор')

# %% [markdown]
# Чи справді різні фактори прогнозування, які були обрані спочатку, впливають на очікувану тривалість життя? Які передбачувані змінні насправді впливають на тривалість життя?

# %%
firstUsed = ['Adult Mortality','infant deaths','Alcohol','BMI','under-five deaths','Population']
print("Дані, що були обрані спочатку (без імунізації та індексів людського розвитку)")
for i in np.arange(0,6):
    result = LifeExData[firstUsed[i]].corr(LifeExData['Life expectancy'])
    if(-0.09<=result<=0 or 0<= result<=0.09): print(firstUsed[i], " Кореляція відсутня ", result)
    if(-0.3<result<=-0.1or 0.1<=result<0.3): print(firstUsed[i], " Низька ", result)
    if(-0.5<result<=-0.3or 0.3<=result<0.5): print(firstUsed[i], " Середня ", result)
    if(-1<=result<=-0.5 or 0.5<=result<=1): print(firstUsed[i], " Висока ", result)
allFactors = Fact
print(" ")
print("Дані, що насправді мають вплив на ОТЖ")
for i in np.arange(0, 18):
    result = LifeExData[allFactors[i]].corr(LifeExData['Life expectancy'])
    if(-0.5<result<=-0.3or 0.3<=result<0.5): print(allFactors[i], " Середня ", result)
    if(-1<=result<=-0.5 or 0.5<=result<=1): print(allFactors[i], " Висока ", result)
# Out:
# Дані, що були обрані спочатку (без імунізації та індексів людського розвитку)
# Adult Mortality  Висока  -0.6963593137699758
# infant deaths  Низька  -0.19655717665526168
# Alcohol  Середня  0.4048767611266021
# BMI  Висока  0.5676935475459864
# under-five deaths  Низька  -0.22252911595117542
# Population  Кореляція відсутня  -0.021538108386786475
#
# Дані, що насправді мають вплив на СТЖ
# Adult Mortality  Висока  -0.6963593137699758
# Alcohol  Середня  0.4048767611266021
# percentage expenditure  Середня  0.3818635033900497
# BMI  Висока  0.5676935475459864
# Polio  Середня  0.4655558059771987
# Diphtheria  Середня  0.47949486434158567
# HIV/AIDS  Висока  -0.5565562534006939
# GDP  Середня  0.4614551926207383
# thinness  1-19 years  Середня  -0.477183191572334
# thinness 5-9 years  Середня  -0.47158360480099726
# Income composition of resources  Висока  0.7247759785960611
# Schooling  Висока  0.7519754627366979

# %% [markdown]
# Чи повинна країна з нижчим значенням очікуваної тривалості життя (<65) збільшити витрати на охорону здоров’я, щоб покращити середню тривалість життя?

# %%
under65 = LifeExData[LifeExData['Life expectancy']<65]
under65s = under65.sample(n = 20)
fig, ax = plt.subplots()
plt.title("Залежність СПЖ від витрат на охорону здоров'я")
ax.set_xticks(np.arange(30, 65))
ax = sb.scatterplot(under65s, x='Life expectancy', y ='Total expenditure', hue = 'Country', )
sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

under65cor = under65['Total expenditure'].corr(under65['Life expectancy'])
print("Витрати на ОЗ мають залежність від СТЖ:")
if(-0.09<=under65cor<=0 or 0<= under65cor<=0.09): print(" Кореляція відсутня ", under65cor)
if(-0.3<under65cor<=-0.1or 0.1<=under65cor<0.3): print(" Низьку ", under65cor)
if(-0.5<under65cor<=-0.3or 0.3<=under65cor<0.5): print( " Середню ", under65cor)
if(-1<=under65cor<=-0.5 or 0.5<=under65cor<=1): print( " Високу ", under65cor)
# Out:
# Витрати на ОЗ мають залежність від СТЖ:
#  Низьку  -0.15674121073082065

# %% [markdown]
# Як рівень дитячої та дорослої смертності впливає на тривалість життя?

# %%
deaths = LifeExData.sample(n = 20)
fig, ax= plt.subplots()
ax.set_xticks(np.arange(30, 100))
plt.xticks(rotation=45)
plt.title("Залежність СПЖ від дитячої смертності")
ax = sb.scatterplot(deaths, x='Life expectancy', y ='infant deaths', hue = 'Country')
sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %%
fig, ax= plt.subplots()
ax.set_xticks(np.arange(30, 100))
plt.xticks(rotation=45)
plt.title("Залежність СПЖ від дорослої смертності")
ax = sb.scatterplot(deaths, x='Life expectancy', y ='Adult Mortality', hue = 'Country')
sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# Чи має очікувана тривалість життя позитивну чи негативну кореляцію зі звичками в їжі, способом життя, фізичними вправами, курінням, вживанням алкоголю тощо.

# %%
habits = LifeExData
result = habits['Life expectancy'].corr(habits['Alcohol'])
if(result>=0): print("Alcohol має позитивну кореляцію")
else: print("Alcohol має негативну кореляцію")
result = habits['Life expectancy'].corr(habits['BMI'])
if(result>=0): print("BMI має позитивну кореляцію")
else: print("BMI має негативну кореляцію")
# Out:
# Alcohol має позитивну кореляцію
# BMI має позитивну кореляцію

# %% [markdown]
# Який вплив навчання в школі на тривалість життя людини?

# %%
schooling = LifeExData.sample(n = 20)
fig, ax= plt.subplots()
ax.set_xticks(np.arange(30, 100))
plt.xticks(rotation=45)
plt.title("Залежність СПЖ від навчання у школі")
ax = sb.scatterplot(schooling, x='Life expectancy', y ='Schooling', hue = 'Country')
sb.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

print("Навчанняу школі має ")
result = LifeExData['Life expectancy'].corr(LifeExData['Schooling'])
if(-0.09<=result<=0 or 0<= result<=0.09): print(" не має залежності ", result)
if(-0.3<result<=-0.1or 0.1<=result<0.3): print(" низьку залежність ", result)
if(-0.5<result<=-0.3or 0.3<=result<0.5): print(" середню залежність ", result)
if(-1<=result<=-0.5 or 0.5<=result<=1): print(" високу залежність ", result)
# Out:
# Навчанняу школі має
#  високу залежність  0.7519754627366979

# %% [markdown]
# Позитивний чи негативний зв’язок очікуваної тривалості життя з вживанням алкоголю?

# %%
habits = LifeExData
result = habits['Life expectancy'].corr(habits['Alcohol'])
if(result>=0): print("Alcohol має позитивний зв'язок до ОТЖ")
else: print("Alcohol має негативний зв'язок до ОТЖ")
# Out:
# Alcohol має позитивний зв'язок до ОТЖ

# %% [markdown]
# Чи зазвичай у густонаселених країнах тривалість життя нижча?

# %%
largePop = LifeExData.sort_values(by ='Population' ,ascending = False)
countryName = pd.unique(largePop['Country'])


sb.set(style="darkgrid")
for i in np.arange(20):
    fig, ax = plt.subplots()
    ax.set_xticks(np.arange(30, 100))
    plt.xticks(rotation=45)
    plt.title(countryName[i])
    sb.scatterplot(LifeExData[LifeExData['Country']==countryName[i]], x='Life expectancy', y ='Population', hue = 'Year')

# %% [markdown]
# Який вплив охоплення імунізацією на очікувану тривалість життя?

# %%
imun = ['Hepatitis B','Measles','Polio','Diphtheria','HIV/AIDS']
for i in np.arange(0,5):
    result = LifeExData[imun[i]].corr(LifeExData['Life expectancy'])
    if(-0.09<=result<=0 or 0<= result<=0.09): print(imun[i], " Кореляція відсутня ", result)
    if(-0.3<result<=-0.1or 0.1<=result<0.3): print(imun[i], " Низька ", result)
    if(-0.5<result<=-0.3or 0.3<=result<0.5): print(imun[i], " Середня ", result)
    if(-1<=result<=-0.5 or 0.5<=result<=1): print(imun[i], " Висока ", result)
# Out:
# Hepatitis B  Низька  0.2567619476049244
# Measles  Низька  -0.15758580377505832
# Polio  Середня  0.4655558059771987
# Diphtheria  Середня  0.47949486434158567
# HIV/AIDS  Висока  -0.5565562534006939
